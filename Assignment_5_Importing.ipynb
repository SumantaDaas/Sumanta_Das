# %% [markdown]
# Assignment 5: Importing, Creating & Packages

# %%
#Assignment 5: Modules & Packages

# Task 1: Create simple functions
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def square(n):
    return n * n

# %%
#This script demonstrates the two different ways to import modules.

# Importing using two different methods
import math_utils
from math_utils import square

# Testing functions
print(f"Addition (10+5): {math_utils.add(10, 5)}")
print(f"Subtraction (20-8): {math_utils.subtract(20, 8)}")
print(f"Square of 4: {square(4)}")
# Out:
# Addition (10+5): 15
# Subtraction (20-8): 12
# Square of 4: 16

# %%
##Modules & Packages

def add(a, b): return a + b
def subtract(a, b): return a - b
def square(n): return n ** 2

# %%
def capitalize_words(text):
    return text.title()

def reverse_string(text):
    return text[::-1]

def word_count(text):
    return len(text.split())

# %%
def apply_discount(price, percent):
    return price * (1 - percent / 100)

def flat_discount(price):
    return price - 50

# %%
def calculate_total(prices):
    return sum(prices)

def apply_tax(amount):
    return amount * 1.05 # Adds 5% tax

# %%
from discount import apply_discount, flat_discount
from billing import calculate_total, apply_tax

# %%
# Task 1 imports
import math_utils
from math_utils import square

# Task 2 import
import string_utils

# Task 4 imports
import shop_package.discount as disc
from shop_package.billing import calculate_total

# Testing Task 1
print(f"Add: {math_utils.add(10, 5)}")
print(f"Square: {square(4)}")

# Testing Task 2
msg = "hello world"
print(f"Reverse: {string_utils.reverse_string(msg)}")

# Testing Task 4 (Package)
print(f"Discounted: {disc.apply_discount(1000, 10)}")
print(f"Total Bill: {calculate_total([100, 200, 300])}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 6
#       3 from math_utils import square
#       5 # Task 2 import
# ----> 6 import string_utils
#       8 # Task 4 imports
#       9 import shop_package.discount as disc
#
# ModuleNotFoundError: No module named 'string_utils'
