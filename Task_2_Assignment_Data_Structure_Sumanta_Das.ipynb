# %% [markdown]
# ## Task 2 : Category Set

# %%
## Create a parallal list for categories and convert to a set ##
categories_list = ["Electronics", "Accessories", "Accessories", "Electronics", "Audio", "Accessories", "Accessories"]
categories_set = set(categories_list)
print(f"Initial set: {categories_set}")
# Out:
# Initial set: {'Accessories', 'Audio', 'Electronics'}

# %%
## add a new category and demonstrate duplicate hanlding ##
categories_set.add("Audio")
